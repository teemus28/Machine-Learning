# %% [markdown]
# <a href="https://colab.research.google.com/github/teemus28/Machine-Learning/blob/main/PCA_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/breast-cancer.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df['diagnosis'].unique()  #classify tumors into M - malignant (cancerous) or B -  benign(non-cancerous)
# Out:
# array(['M', 'B'], dtype=object)

# %%
x = df.iloc[:,2:]
x.sample(5)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 302        20.09         23.86          134.70     1247.0          0.10800
# 159        10.90         12.96           68.69      366.8          0.07515
# 212        28.11         18.47          188.50     2499.0          0.11420
# 35         16.74         21.59          110.10      869.5          0.09610
# 44         13.17         21.81           85.42      531.5          0.09714
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 302           0.18380         0.22830             0.128000         0.2249
# 159           0.03718         0.00309             0.006588         0.1442
# 212           0.15160         0.32010             0.159500         0.1648
# 35            0.13360         0.13480             0.060180         0.1896
# 44            0.10470         0.08259             0.052520         0.1746
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
y = df.iloc[:,1]
y = pd.DataFrame(y)
y.sample(5)
# Out:
#     diagnosis
# 507         B
# 530         B
# 235         B
# 219         M
# 298         B

# %%
# !pip install ydata_profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
# from ydata_profiling import ProfileReport
# pf = ProfileReport(df)
# pf.to_notebook_iframe()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 378       13.660         15.15           88.27      580.6          0.08268
# 374       13.690         16.07           87.84      579.1          0.08302
# 468       17.600         23.33          119.00      980.5          0.09289
# 495       14.870         20.21           96.12      680.9          0.09587
# 470        9.667         18.49           61.49      289.1          0.08946
# ..           ...           ...             ...        ...              ...
# 203       13.810         23.75           91.56      597.8          0.13230
# 403       12.940         16.17           83.18      507.6          0.09879
# 340       14.420         16.54           94.15      641.2          0.09751
# 113       10.510         20.19           68.64      334.2          0.11220
# 375       16.170         16.07          106.30      788.5          0.09880
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pre = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pre)
# Out:
# 0.9298245614035088

# %% [markdown]
# Applying PCA

# %%
#1 scaling

#we have to reduce dimensions of x from 32 to any , so we apply on x only
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit(x)
# Out:
# StandardScaler()

# %%
x_scale = scale.transform(x)

# %%
#2 PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
x_reduced = pca.fit_transform(x_scale)
x_reduced
# Out:
# array([[ 9.19283683,  1.94858307],
#        [ 2.3878018 , -3.76817174],
#        [ 5.73389628, -1.0751738 ],
#        ...,
#        [ 1.25617928, -1.90229671],
#        [10.37479406,  1.6720101 ],
#        [-5.4752433 , -0.67063679]])

# %%
pd.DataFrame(x_reduced)
# Out:
#              0          1
# 0     9.192837   1.948583
# 1     2.387802  -3.768172
# 2     5.733896  -1.075174
# 3     7.122953  10.275589
# 4     3.935302  -1.948072
# ..         ...        ...
# 564   6.439315  -3.576817
# 565   3.793382  -3.584048
# 566   1.256179  -1.902297
# 567  10.374794   1.672010
# 568  -5.475243  -0.670637
#
# [569 rows x 2 columns]

# %%
pca.explained_variance_
# Out:
# array([13.30499079,  5.7013746 ])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.scatter(x_reduced[:,0],x_reduced[:,1],cmap='plasma')

# plt.xlabel('PC1')
# plt.ylabel('PC2')
# Out:
# <ipython-input-103-20442ee19987>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x_reduced[:,0],x_reduced[:,1],cmap='plasma')

# %%
x_reduced
# Out:
# array([[ 9.19283683,  1.94858307],
#        [ 2.3878018 , -3.76817174],
#        [ 5.73389628, -1.0751738 ],
#        ...,
#        [ 1.25617928, -1.90229671],
#        [10.37479406,  1.6720101 ],
#        [-5.4752433 , -0.67063679]])

# %%
y
# Out:
#     diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train_red,x_test_red,y_train,y_test = train_test_split(x_reduced,y,test_size=0.2)

# %%
x_train_red.shape
# Out:
# (455, 2)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train_red,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pre_red = lr.predict(x_test_red)

# %%
accuracy_score(y_test,y_pre_red)  #0.9298245614035088 , previous
# Out:
# 0.9385964912280702
