# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Wine dataset.csv")

# %%
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df = df.iloc[:,1:3]

# %%
df
# Out:
#      Alcohol  Malic acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %% [markdown]
# Scaling - Standardization

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x = df['Malic acid'],y=df['Alcohol'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaled = scaler.transform(df)

# %%
df_scaled = pd.DataFrame(scaled,columns = df.columns)

# %%
df_scaled
# Out:
#       Alcohol  Malic acid
# 0    1.518613   -0.562250
# 1    0.246290   -0.499413
# 2    0.196879    0.021231
# 3    1.691550   -0.346811
# 4    0.295700    0.227694
# ..        ...         ...
# 173  0.876275    2.974543
# 174  0.493343    1.412609
# 175  0.332758    1.744744
# 176  0.209232    0.227694
# 177  1.395086    1.583165
#
# [178 rows x 2 columns]

# %%
df_scaled.describe()
# Out:
#             Alcohol    Malic acid
# count  1.780000e+02  1.780000e+02
# mean  -8.382808e-16 -1.197544e-16
# std    1.002821e+00  1.002821e+00
# min   -2.434235e+00 -1.432983e+00
# 25%   -7.882448e-01 -6.587486e-01
# 50%    6.099988e-02 -4.231120e-01
# 75%    8.361286e-01  6.697929e-01
# max    2.259772e+00  3.109192e+00

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2 , figsize=(12,5))
ax1.scatter(df['Malic acid'],df['Alcohol'])
ax2.scatter(df_scaled['Malic acid'],df_scaled['Alcohol'],color='r')

# %% [markdown]
# Normalization - MinMaxScaler

# %%
df.head()
# Out:
#    Alcohol  Malic acid
# 0    14.23        1.71
# 1    13.20        1.78
# 2    13.16        2.36
# 3    14.37        1.95
# 4    13.24        2.59

# %%
from sklearn.preprocessing import MinMaxScaler
scale_n = MinMaxScaler()

# %%
scaled_n = scale_n.fit_transform(df)

# %%
df_scaled_n = pd.DataFrame(scaled_n,columns = df.columns)

# %%
df_scaled_n
# Out:
#       Alcohol  Malic acid
# 0    0.842105    0.191700
# 1    0.571053    0.205534
# 2    0.560526    0.320158
# 3    0.878947    0.239130
# 4    0.581579    0.365613
# ..        ...         ...
# 173  0.705263    0.970356
# 174  0.623684    0.626482
# 175  0.589474    0.699605
# 176  0.563158    0.365613
# 177  0.815789    0.664032
#
# [178 rows x 2 columns]

# %%
df_scaled_n.describe()
# Out:
#           Alcohol  Malic acid
# count  178.000000  178.000000
# mean     0.518584    0.315484
# std      0.213639    0.220780
# min      0.000000    0.000000
# 25%      0.350658    0.170455
# 50%      0.531579    0.222332
# 75%      0.696711    0.462945
# max      1.000000    1.000000

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2 , figsize=(12,5))
ax1.scatter(df['Malic acid'],df['Alcohol'])
ax2.scatter(df_scaled_n['Malic acid'],df_scaled_n['Alcohol'],color='r')

# %%
import seaborn as sbn

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2 , figsize=(12,5))

ax1.set_title('Standadization')
sbn.kdeplot(df_scaled['Malic acid'],ax = ax1)
sbn.kdeplot(df_scaled['Alcohol'],ax = ax1)

ax2.set_title('Normalization')
sbn.kdeplot(df_scaled_n['Malic acid'],ax = ax2)
sbn.kdeplot(df_scaled_n['Alcohol'],ax = ax2)
# Out:
# <Axes: title={'center': 'Normalization'}, xlabel='Malic acid', ylabel='Density'>

# %% [markdown]
# Feature Encoding ,
# convert to numeric  -  OHE or Ordinal Encoder

# %%
df_2 = pd.read_csv("/content/covid_toy.csv")

# %%
df_2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='mean')
fever = si.fit_transform(df_2[['fever']])

# %%
fever = pd.DataFrame(fever)

# %%
fever
# Out:
#         0
# 0   103.0
# 1   100.0
# 2   101.0
# 3    98.0
# 4   101.0
# ..    ...
# 95  104.0
# 96  101.0
# 97  101.0
# 98   98.0
# 99   98.0
#
# [100 rows x 1 columns]

# %%
df_2['fever']=fever

# %%
df_2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      100 non-null    float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df_2.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
# gender - OneHotEncoder
# cough - ordinal
# city - ohe
# has_covid - ordinal

# %%
df_2['cough'].unique()
# Out:
# array(['Mild', 'Strong'], dtype=object)

# %%
df_2['city'].unique()
# Out:
# array(['Kolkata', 'Delhi', 'Mumbai', 'Bangalore'], dtype=object)

# %%
df_2['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_2['has_covid'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df_2['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df_2['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
ohe = OneHotEncoder()
encode = ohe.fit_transform(df_2[['gender','city']]).toarray()
fea = ohe.categories_
import numpy as np
feature = np.array(fea)

# %%
one_hot_encoded_data = pd.get_dummies(df_2, columns = ['gender','city'],dtype=int)
print(one_hot_encoded_data)
# Out:
#     age  fever   cough has_covid  gender_Female  gender_Male  city_Bangalore  \
# 0    60  103.0    Mild        No              0            1               0
# 1    27  100.0    Mild       Yes              0            1               0
# 2    42  101.0    Mild        No              0            1               0
# 3    31   98.0    Mild        No              1            0               0
# 4    65  101.0    Mild        No              1            0               0
# ..  ...    ...     ...       ...            ...          ...             ...
# 95   12  104.0    Mild        No              1            0               1
# 96   51  101.0  Strong       Yes              1            0               0
# 97   20  101.0    Mild        No              1            0               1
# 98    5   98.0  Strong        No              1            0               0
# 99   10   98.0  Strong       Yes              1            0               0
#
#     city_Delhi  city_Kolkata  city_Mumbai
# ...

# %%
pd.DataFrame(one_hot_encoded_data)
# Out:
#     age  fever   cough has_covid  gender_Female  gender_Male  city_Bangalore  \
# 0    60  103.0    Mild        No              0            1               0
# 1    27  100.0    Mild       Yes              0            1               0
# 2    42  101.0    Mild        No              0            1               0
# 3    31   98.0    Mild        No              1            0               0
# 4    65  101.0    Mild        No              1            0               0
# ..  ...    ...     ...       ...            ...          ...             ...
# 95   12  104.0    Mild        No              1            0               1
# 96   51  101.0  Strong       Yes              1            0               0
# 97   20  101.0    Mild        No              1            0               1
# 98    5   98.0  Strong        No              1            0               0
# 99   10   98.0  Strong       Yes              1            0               0
#
#     city_Delhi  city_Kolkata  city_Mumbai
# ...

# %%
pd.get_dummies(df_2, columns = ['gender','city'],drop_first=True,dtype=int)  #drop first column of both feature
# Out:
#     age  fever   cough has_covid  gender_Male  city_Delhi  city_Kolkata  \
# 0    60  103.0    Mild        No            1           0             1
# 1    27  100.0    Mild       Yes            1           1             0
# 2    42  101.0    Mild        No            1           1             0
# 3    31   98.0    Mild        No            0           0             1
# 4    65  101.0    Mild        No            0           0             0
# ..  ...    ...     ...       ...          ...         ...           ...
# 95   12  104.0    Mild        No            0           0             0
# 96   51  101.0  Strong       Yes            0           0             1
# 97   20  101.0    Mild        No            0           0             0
# 98    5   98.0  Strong        No            0           0             0
# 99   10   98.0  Strong       Yes            0           0             1
#
#     city_Mumbai
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
df_2.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
count = df_2['city'].value_counts()

# %%
con = count[count<=20].index

# %%
con
# Out:
# Index(['Mumbai'], dtype='object', name='city')

# %%
pd.get_dummies(df_2['city'].replace(con,'other'),dtype=int)
# Out:
#     Bangalore  Delhi  Kolkata  other
# 0           0      0        1      0
# 1           0      1        0      0
# 2           0      1        0      0
# 3           0      0        1      0
# 4           0      0        0      1
# ..        ...    ...      ...    ...
# 95          1      0        0      0
# 96          0      0        1      0
# 97          1      0        0      0
# 98          0      0        0      1
# 99          0      0        1      0
#
# [100 rows x 4 columns]

# %% [markdown]
# Ordinal Encoding

# %%
df_2.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df_3 = df_2.loc[:,['cough','has_covid']]
df_3.head()
# Out:
#   cough has_covid
# 0  Mild        No
# 1  Mild       Yes
# 2  Mild        No
# 3  Mild        No
# 4  Mild        No

# %%
#cough , has_covid

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

# %%
fea = oe.fit_transform(df_2[['cough','has_covid']])

# %%
encoded_data = pd.DataFrame(fea,columns=df_3.columns)

# %%
pd.concat([df_2,encoded_data],axis=1)
# Out:
#     age  gender  fever   cough       city  has_covid  cough  has_covid
# 0    60    Male  103.0    Mild    Kolkata         No    0.0        0.0
# 1    27    Male  100.0    Mild      Delhi        Yes    0.0        1.0
# 2    42    Male  101.0    Mild      Delhi         No    0.0        0.0
# 3    31  Female   98.0    Mild    Kolkata         No    0.0        0.0
# 4    65  Female  101.0    Mild     Mumbai         No    0.0        0.0
# ..  ...     ...    ...     ...        ...        ...    ...        ...
# 95   12  Female  104.0    Mild  Bangalore         No    0.0        0.0
# 96   51  Female  101.0  Strong    Kolkata        Yes    1.0        1.0
# 97   20  Female  101.0    Mild  Bangalore         No    0.0        0.0
# 98    5  Female   98.0  Strong     Mumbai         No    1.0        0.0
# 99   10  Female   98.0  Strong    Kolkata        Yes    1.0        1.0
#
# [100 rows x 8 columns]
