# %% [markdown]
# <a href="https://colab.research.google.com/github/teemus28/Machine-Learning/blob/main/EDA_Univariant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.1 EDA identify numrical and categorical columns - Univariant Analysis

import pandas as pd

df = pd.read_csv('/content/titanic-dataset.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# PassengerId - NA
# Survided - C
# Pclass  - C
# Name  - NA
# Sex/Gender - C
# Age  - N
# SibSp - C
# ParCh - C
# Ticket # - NA
# Fare - N
# Cabin - NA
# Embarked - C

# %%
# 1.2 EDA - Categorical Data Analysis

import seaborn as sbn

sbn.countplot(x=df['Survived'])

#df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#df['Pclass'].value_counts().plot(kind='bar')

sbn.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sbn.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# 1.2 EDA - Numerical Data Analysis (Uni variant - One Column )

# Histogram graph
import matplotlib.pyplot as plt

plt.hist(df['Age'], bins=50) # What is bining in histogram ??
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1b509b7c86ad> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 plt.hist(df['Age'], bins=30)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # New Section

# %%
# 1.2 EDA - Numerical Data Analysis (Uni variant - One Column )

# Distplot graph

sbn.displot(x=df['Age'], kde=True,
    stat="density", kde_kws=dict(cut=3))

# %%
# 1.2 EDA - Numerical Data Analysis (Uni variant - One Column )

# BoxPlot graph


sbn.boxplot(df['Age'])
# import numpy as np

# mydt = np.array([10,20,30,40,50,60,70])
# Out:
# <Axes: ylabel='Age'>
